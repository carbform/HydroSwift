# %%
import hydroswift as hs

# %%
basins = hs.wris.stations(variable='gwl', basin = 'all')
basins
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 basins = hs.wris.stations(variable='gwl')
#       2 basins
#
# TypeError: _WrisNamespace.stations() missing 1 required positional argument: 'basin'

# %%
hs.wris.download(variable='gwl',basin = 'all', start_date='1990-01-01', 
end_date='2025-12-31', overwrite=True)
# Out:
# Searching WRIS database for basin='Brahmani and Baitarni', Variables=gwl from 1990-01-01 to 2025-12-31...This might take a while...
#
# Dataset: groundwater_level
# Using cached station discovery
# All stations already downloaded — skipping download step.
#
# -------------------------------------------------------------
# Download Summary
# -------------------------------------------------------------
# Dataset           Selected  Attempted  Downloaded  Skipped  NoData/Fail  Time(s)
# -------------------------------------------------------------
# groundwater_level 0         0          0           0        0            0.0
# -------------------------------------------------------------
# Output directory: output/wris/brahmani and baitarni
# -------------------------------------------------------------
# Searching WRIS database for basin='Cauvery', Variables=gwl from 1990-01-01 to 2025-12-31...This might take a while...
#
# Dataset: groundwater_level
# Using cached station discovery
# ...
